# %%
ans.1
For Loop:
A for loop is ideal when you know the number of times you want to repeat a specific task. It's commonly used for iterating over a fixed sequence like a list, tuple, range, or string. The syntax of a for loop is generally simpler and more concise compared to a while loop.


for i in range(1, 6):
    print(i)

    
    and....
    
    While Loop:
A while loop is suitable when you want to repeat a task until a certain condition becomes false. The loop will continue to execute as long as the specified condition is true. It's often used when the exact number of iterations is uncertain.
Example: Counting down from 5 to 1 using a while loop in Python:
    
    
    countdown = 5
while countdown > 0:
    print(countdown)
    countdown -= 1

    
    ans.2
    # Using for loop to calculate the sum of the first 10 natural numbers
sum_of_numbers = 0
for num in range(1, 11):
    sum_of_numbers += num

# Using for loop to calculate the product of the first 10 natural numbers
product_of_numbers = 1
for num in range(1, 11):
    product_of_numbers *= num

print("Sum of the first 10 natural numbers:", sum_of_numbers)
print("Product of the first 10 natural numbers:", product_of_numbers)


    # Using while loop to calculate the sum of the first 10 natural numbers
sum_of_numbers = 0
num = 1
while num <= 10:
    sum_of_numbers += num
    num += 1

# Using while loop to calculate the product of the first 10 natural numbers
product_of_numbers = 1
num = 1
while num <= 10:
    product_of_numbers *= num
    num += 1

print("Sum of the first 10 natural numbers:", sum_of_numbers)
print("Product of the first 10 natural numbers:", product_of_numbers)


ans.3

def calculate_electricity_bill(units):
    if units <= 100:
        charge_per_unit = 4.5
    elif units <= 200:
        charge_per_unit = 6
    elif units <= 300:
        charge_per_unit = 10
    else:
        charge_per_unit = 20

    total_bill = units * charge_per_unit
    return total_bill

# Input the number of units consumed by the household
units_consumed = float(input("Enter the number of units consumed: "))

electricity_bill = calculate_electricity_bill(units_consumed)
print("Electricity Bill: Rs.", electricity_bill)


ans.4

for loop use
cubes_divisible_by_4_or_5 = []

for num in range(1, 101):
    cube = num ** 3
    if cube % 4 == 0 or cube % 5 == 0:
        cubes_divisible_by_4_or_5.append(cube)

print(cubes_divisible_by_4_or_5)


while loop

cubes_divisible_by_4_or_5 = []
num = 1

while num <= 100:
    cube = num ** 3
    if cube % 4 == 0 or cube % 5 == 0:
        cubes_divisible_by_4_or_5.append(cube)
    num += 1

print(cubes_divisible_by_4_or_5)

These are the cubes of the numbers from 1 to 100 that are divisible by 4 or 5.


ans.5

Sure! To count the vowels in the given string, you can use the following Python program:
    
    def count_vowels(input_string):
    vowels = "aeiouAEIOU"
    vowel_count = 0

    for char in input_string:
        if char in vowels:
            vowel_count += 1

    return vowel_count

string = "I want to become a data scientist"
vowel_count = count_vowels(string)
print("Number of vowels in the string:", vowel_count)



The program defines a function count_vowels that iterates through each character in the input string and checks if it is a vowel. If the character is a vowel, it increments the vowel_count variable. Finally, it returns the total count of vowels in the given string. In this case, the string contains 10 vowels: 'I', 'a', 'a', 'o', 'e', 'o', 'e', 'a', 'a', and 'i'.
